# %% [markdown]
# # Exploració dataset Restaurants

# %%
import pandas as pd
import fuzzysearch as fz


from dataclasses import dataclass
from typing import Optional, TextIO, List, Tuple

# %%
restaurant_list = pd.read_csv("restaurants.csv")

# %%
restaurant_list.columns
# Out:
# Index(['register_id', 'name', 'institution_id', 'institution_name', 'created',
#        'modified', 'addresses_roadtype_id', 'addresses_roadtype_name',
#        'addresses_road_id', 'addresses_road_name',
#        'addresses_start_street_number', 'addresses_end_street_number',
#        'addresses_neighborhood_id', 'addresses_neighborhood_name',
#        'addresses_district_id', 'addresses_district_name',
#        'addresses_zip_code', 'addresses_town', 'addresses_main_address',
#        'addresses_type', 'values_id', 'values_attribute_id', 'values_category',
#        'values_attribute_name', 'values_value', 'values_outstanding',
#        'values_description', 'secondary_filters_id', 'secondary_filters_name',
#        'secondary_filters_fullpath', 'secondary_filters_tree',
#        'secondary_filters_asia_id', 'geo_epgs_25831_x', 'geo_epgs_25831_y',
#        'geo_epgs_4326_x', 'geo_epgs_4326_y'],
#       dtype='object')

# %%
@dataclass
class Adress:
    road_id: int
    road_name: str
    street_n: int #POT SER UN RANG -> si es rang agafem mediana
    nb_id: int #Id del barri
    nb_name: str #nom del barri
    dist_id: int
    dist_name: str
    zip_code: int
    #LA MAIN ADRESS??

# %%
@dataclass 
#GUARDAR ID COM INT O STR?
class Restaurant:
    id: int
    name: str
    institution: Tuple[int,str]
    adress: Adress
    tlf: str
    secondary: Tuple[int,str]
    coords: Tuple[float,float]
#    def __init__(self,row):

# %%
# To be implemented

for index,row in restaurant_list.iterrows():
    new_adress: Adress()
    new_restaurant: Restaurant()
# Out:
#   Input In [116]
#     for index,row in restaurant_list.iterrows():
#                                                 ^
# SyntaxError: incomplete input

# %%
for index,valu
# Out:
# (0,
#  register_id                                                           ﻿92218104359
#  name                                               Restaurant Pizzeria La Briciola
#  institution_id                                                                 NaN
#  institution_name                                                               NaN
#  created                                                  1992-08-05T00:00:00+02:00
#  modified                                          2022-03-15T18:09:43.795606+01:00
#  addresses_roadtype_id                                                          NaN
#  addresses_roadtype_name                                                        NaN
#  addresses_road_id                                                         235208.0
#  addresses_road_name                                                   C Olzinelles
#  addresses_start_street_number                                                 19.0
# ...

# %%
len(restaurant_list)
# Out:
# 2543

# %%
restaurant_list[restaurant_list["addresses_end_street_number"].isna()]
# Out:
#        register_id                                          name  \
# 0     ﻿92218104359               Restaurant Pizzeria La Briciola
# 1     ﻿99400594025                            Restaurant Crosmas
# 2     ﻿99400594040                               Restaurant Zian
# 3     ﻿99400594058                       Restaurant Mesón 7lunas
# 4     ﻿99400594111                Restaurant Motta Cocina Fusión
# ...            ...                                           ...
# 2518  ﻿99400637680                            Restaurant Narciso
# 2519  ﻿99400621036                         Restaurant We Bistrot
# 2521  ﻿99400651432                             Restaurant Virens
# 2527  ﻿99400685965  Notícia: Últims bars amb caliu a Sant Antoni
# 2530  ﻿99400685950            Notícia: Neix Cuides UIC Barcelona
#
#       institution_id            institution_name  \
# 0                NaN                         NaN
# 1                NaN                         NaN
# ...
